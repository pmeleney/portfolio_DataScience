# %% [markdown]
# The purpose of this notebook is to create a function that takes as inputs a dataframe and a dictonary and fills in the numeric features as classes from the dictionary

# %%
import pandas as pd
import xlrd

# %%
def fill_from_dictionary(path_to_data, path_to_dictionary):
    data = pd.read_csv(path_to_data)
    
    #Lower all column headders in data
    columns_lowered = []
    for col in data.columns:
        columns_lowered.append(col.lower())

    data.columns = columns_lowered
    
    #Read in data dictionary
    xl = pd.ExcelFile(path_to_dictionary)
    
    #make dictionary of each sheet from dictionary excel file
    d= {}
    for x in xl.sheet_names[1:]:
        d["{0}".format(x).lower()] = pd.read_excel(path_to_dictionary, sheetname= x, index_col=0)
    
    
    for key in d:
        d2 = d[key].to_dict()
        for key2 in d2:
            data[key].replace(d2[key2], inplace = True)
            data[key].fillna('unknown', inplace = True)
    return(data)

# %%
data = fill_from_dictionary('../raw_data/properties_2016.csv', '../raw_data/zillow_data_dictionary.xlsx')
# Out:
# C:\Users\pmele\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2787: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
data.head()
# Out:
#    parcelid airconditioningtypeid architecturalstyletypeid  basementsqft  \
# 0  10754147               unknown                  unknown           NaN
# 1  10759547               unknown                  unknown           NaN
# 2  10843547               unknown                  unknown           NaN
# 3  10859147               unknown                  unknown           NaN
# 4  10879947               unknown                  unknown           NaN
#
#    bathroomcnt  bedroomcnt                                buildingclasstypeid  \
# 0          0.0         0.0                                            unknown
# 1          0.0         0.0                                            unknown
# 2          0.0         0.0                                            unknown
# 3          0.0         0.0  Buildings having exterior walls built of a non...
# 4          0.0         0.0     Buildings having wood or wood and steel frames
#
# ...

# %%
for key in d.keys():
    data[key]

# %%
key
# Out:
# 'buildingclasstypeid'

# %%
d[key].to_dict()
# Out:
# {'BuildingClassDesc': {1: 'Buildings having fireproofed structural steel frames carrying all wall, floor and roof loads. Wall, floor and roof structures are built of non-combustible materials.',
#   2: 'Buildings having fireproofed reinforced concrete frames carrying all wall floor and roof loads which are all non-combustible.',
#   3: 'Buildings having exterior walls built of a non-combustible material such as brick, concrete, block or poured concrete. Interior partitions and roof structures are built of combustible materials. Floor may be concrete or wood frame.',
#   4: 'Buildings having wood or wood and steel frames',
#   5: 'Specialized buildings that do not fit in any of the above categories'}}

# %%
d2 = d[key].to_dict()
for key in d:
    for key2 in d2:
        data[key].replace(d2[key2], inplace = True)

# %%
data
# Out:
#           parcelid                              airconditioningtypeid  \
# 0         10754147                                                NaN
# 1         10759547                                                NaN
# 2         10843547                                                NaN
# 3         10859147                                                NaN
# 4         10879947                                                NaN
# 5         10898347                                                NaN
# 6         10933547                                                NaN
# 7         10940747                                                NaN
# 8         10954547                                                NaN
# 9         10976347                                                NaN
# 10        11073947                                                NaN
# 11        11114347                                                NaN
# ...

# %%
data = pd.read_csv('../raw_data/properties_2016.csv')
# Out:
# C:\Users\pmele\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2683: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Ensure that all columns headders are lowered

columns_lowered = []
for col in data.columns:
    columns_lowered.append(col.lower())

data.columns = columns_lowered

# %%
xl = pd.ExcelFile('../raw_data/zillow_data_dictionary.xlsx')

# %%
xl.sheet_names[1:]
# Out:
# ['HeatingOrSystemTypeID',
#  'PropertyLandUseTypeID',
#  'StoryTypeID',
#  'AirConditioningTypeID',
#  'ArchitecturalStyleTypeID',
#  'TypeConstructionTypeID',
#  'BuildingClassTypeID']

# %%
d= {}
for x in xl.sheet_names[1:]:
    d["{0}".format(x).lower()] = pd.read_excel('../raw_data/zillow_data_dictionary.xlsx', sheetname= x, index_col=0)

# %%
d['heatingorsystemtypeid']
# Out:
#                       HeatingOrSystemDesc
# HeatingOrSystemTypeID
# 1                               Baseboard
# 2                                 Central
# 3                                    Coal
# 4                              Convection
# 5                                Electric
# 6                              Forced air
# 7                              Floor/Wall
# 8                                     Gas
# 9                             Geo Thermal
# 10                                Gravity
# 11                              Heat Pump
# 12                              Hot Water
# 13                                   None
# 14                                  Other
# 15                                    Oil
# 16                                Partial
# 17                                Propane
# 18                                Radiant
# 19                                  Steam
# 20                                  Solar
# 21                        Space/Suspended
# ...

# %%
d2 = d['heatingorsystemtypeid'].to_dict()
l = []
for key in d2.keys():
    l.append(key)

data.heatingorsystemtypeid.replace(d2[l[0]], inplace=True)

# %%
data.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
# Out:
# {'airconditioningtypeid':     AirConditioningTypeID AirConditioningDesc
#  0                       1             Central
#  1                       2       Chilled Water
#  2                       3  Evaporative Cooler
#  3                       4         Geo Thermal
#  4                       5                None
#  5                       6               Other
#  6                       7    Packaged AC Unit
#  7                       8             Partial
#  8                       9       Refrigeration
#  9                      10         Ventilation
#  10                     11           Wall Unit
#  11                     12         Window Unit
#  12                     13                 Yes,
#  'architecturalstyletypeid':     ArchitecturalStyleTypeID         ArchitecturalStyleDesc
#  0                          1                        A-Frame
#  1                          2                       Bungalow
#  2                          3                       Cape Cod
# ...

# %%
d = pd.read_excel('../raw_data/zillow_data_dictionary.xlsx', sheetname='HeatingOrSystemTypeID', index_col=0)

# %%
d2 = d.to_dict()

# %%
l = []
for key in d2.keys():
    l.append(key)

# %%
d2[l[0]]
# Out:
# {1: 'Baseboard',
#  2: 'Central',
#  3: 'Coal',
#  4: 'Convection',
#  5: 'Electric',
#  6: 'Forced air',
#  7: 'Floor/Wall',
#  8: 'Gas',
#  9: 'Geo Thermal',
#  10: 'Gravity',
#  11: 'Heat Pump',
#  12: 'Hot Water',
#  13: 'None',
#  14: 'Other',
#  15: 'Oil',
#  16: 'Partial',
#  17: 'Propane',
#  18: 'Radiant',
#  19: 'Steam',
#  20: 'Solar',
#  21: 'Space/Suspended',
#  22: 'Vent',
#  23: 'Wood Burning',
#  24: 'Yes',
#  25: 'Zone'}
