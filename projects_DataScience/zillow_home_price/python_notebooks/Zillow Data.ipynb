# %%
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
train_target = pd.read_csv('../raw_data/train_2016_v2.csv', index_col = 'parcelid')
test_zeros = pd.read_csv('../raw_data/sample_submission.csv', index_col = 'ParcelId')
data = pd.read_csv('../raw_data/properties_2016.csv', index_col='parcelid', low_memory=False)

# %%
print('train shape: ', train_target.shape, 'data shape: ', data.shape)
# Out:
# train shape:  (90275, 2) data shape:  (2985217, 57)

# %%
train_target.head()
# Out:
#           logerror transactiondate
# parcelid
# 11016594    0.0276      2016-01-01
# 14366692   -0.1684      2016-01-01
# 12098116   -0.0040      2016-01-01
# 12643413    0.0218      2016-01-02
# 14432541   -0.0050      2016-01-02

# %%
data.head()
# Out:
#           airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# parcelid
# 10754147                    NaN                       NaN           NaN
# 10759547                    NaN                       NaN           NaN
# 10843547                    NaN                       NaN           NaN
# 10859147                    NaN                       NaN           NaN
# 10879947                    NaN                       NaN           NaN
#
#           bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# parcelid
# 10754147          0.0         0.0                  NaN                    NaN
# 10759547          0.0         0.0                  NaN                    NaN
# 10843547          0.0         0.0                  NaN                    NaN
# 10859147          0.0         0.0                  3.0                    7.0
# 10879947          0.0         0.0                  4.0                    NaN
#
# ...

# %% [markdown]
# ## Join the two dataframes together

# %%
df = train_target.join(data)

# %%
df.head()
# Out:
#           logerror transactiondate  airconditioningtypeid  \
# parcelid
# 10711738    0.0276      2016-08-02                    1.0
# 10711755   -0.0182      2016-08-02                    1.0
# 10711805   -0.1009      2016-05-03                    1.0
# 10711816   -0.0121      2016-04-05                    1.0
# 10711858   -0.0481      2016-07-15                    1.0
#
#           architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# parcelid
# 10711738                       NaN           NaN          3.0         4.0
# 10711755                       NaN           NaN          3.0         3.0
# 10711805                       NaN           NaN          2.0         3.0
# 10711816                       NaN           NaN          2.0         4.0
# 10711858                       NaN           NaN          2.0         4.0
#
#           buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# parcelid
# ...

# %%
df = df.sort_values(by='transactiondate')

# %% [markdown]
# ## Test-train split

# %%
df_train = df

# %%
df_train.head()
# Out:
#           logerror transactiondate  airconditioningtypeid  \
# parcelid
# 12098116   -0.0040      2016-01-01                    1.0
# 14366692   -0.1684      2016-01-01                    NaN
# 11016594    0.0276      2016-01-01                    1.0
# 11509835   -0.2705      2016-01-02                    1.0
# 12286022    0.0440      2016-01-02                    NaN
#
#           architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# parcelid
# 12098116                       NaN           NaN          3.0         2.0
# 14366692                       NaN           NaN          3.5         4.0
# 11016594                       NaN           NaN          2.0         3.0
# 11509835                       NaN           NaN          4.0         4.0
# 12286022                       NaN           NaN          1.0         2.0
#
#           buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# parcelid
# ...
